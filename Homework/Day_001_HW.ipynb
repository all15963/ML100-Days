# %% [markdown]
# # 作業1：
#
# # 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：

# %% [markdown]
# ## 1.  你選的這組資料為何重要
#
# ### 我選了一個由新聞來預測股價的比賽，那股票簡單來講就是買方跟賣方之間的角力，誰強股價就往哪邊跑。而我認為藉由新聞(消息面)多少會動搖買賣家藉此影響股價的波動，對於做短線的人來說是可以做為買賣的依據

# %% [markdown]
# ## 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# ### Market data 由 Intrinio 提供
# ![Intrinio](1.png)
#
# ### News data 由 Thomson Reuters 提供
# ![Thomson Reuters](2.png)

# %% [markdown]
# ## 3. 蒐集而來的資料型態為何
#
# ### Market data 和 News data 皆有類別資料與數值資料(離散&連續)

# %% [markdown]
# ## 4. 這組資料想解決的問題如何評估
#
# ### 我認為既然是利用新聞來預測股價，那一定會有特定字眼是影響力較大，以及該新聞的討論度是否熱烈，都可能動搖大多數的投資者做買賣

# %% [markdown]
# # 作業2：
#
# # 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

# %% [markdown]
# ## 1. 核心問題為何
#
# ### 提升業績:顧客傾向搭乘我的車隊比例變高、一天的載客量提高、共同合作的店家增加或開始出現

# %% [markdown]
# ## 2. 資料從何而來
#
# ### 資料可藉由APP、車內裝載統計的系統、合作店家來取得。而顧客的評價、接客地點、合作店家之方案都可能影響業績的提升

# %% [markdown]
# ## 3. 蒐集而來的資料型態為何
#
# ### 類別型資料:顧客的星級評等
# ### 連續型資料:搭乘的里程數
# ### 離散型資料:乘車人數
# ### 字符型資料:顧客評價

# %% [markdown]
# ## 4. 你要回答的問題，其如何評估
#
# ### 選取可能影響業績的因素作為分析的依據，從裡面找出對結果影響力強的變數，並做為參考依據。
# ### 比方說，車隊中某部車差評連連，那可能從文字去找出最多人所抱怨的原因，並加以改進以提升顧客滿意度

# %% [markdown]
# # 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(a,b):

    mse= (1/len(a)) * sum((b-a.mean())**2)
    return mse

def mean_absolute_error(y, yp):

    mae = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 7650.641
# The Mean absolute error is 12.650
